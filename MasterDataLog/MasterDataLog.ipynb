# %%
import numpy,time,datetime,subprocess,os

# %%
datadir="/mnt/10TBHDD/data/"
daystocheckcutoff=7

def get_subdirectories(directory):
    """
    Returns an array of subdirectories in the given directory.

    Args:
    - directory (str): The path to the directory.

    Returns:
    - list: A list containing the names of subdirectories in the specified directory.
    """
    subdirectories = [d for d in os.listdir(directory) if os.path.isdir(os.path.join(directory, d))]
    return subdirectories

def find_recent_directories(directory,dayscutoff):
    """
    Finds directories that have been modified within a specified number of days.

    Args:
    - directory (str): The path to the directory to search for recently modified directories.
    - dayscutoff (float): The threshold in days for considering directories as recent modifications.

    Returns:
    - recentfiles (list): A list of directory names that have been modified within the specified dayscutoff.
    """
    filecheck=subprocess.check_output("stat "+directory+"* |grep 'File\|Modify'",shell=True)
    filecheck=str(filecheck)
    filecheck=filecheck.split('File')
    now=datetime.datetime.now()
    for i in range(len(filecheck)):
        filecheck[i]=filecheck[i].split('\\n')
    del(filecheck[0])
    for i in filecheck:
        del(i[-1])
        i[0]=i[0][2:]
        i[1]=i[1][8:-9]
        i[1]=(now-datetime.datetime.strptime(i[1],'%Y-%m-%d %H:%M:%S.%f')).total_seconds()/86400.0
    filecheck=numpy.array(filecheck)
    filecheck=numpy.array(filecheck)
    recentfiles=[]
    for file in filecheck:
        if float(file[1])<dayscutoff:
            recentfiles.append(file[0])
    return recentfiles

def remove_elements(original_array, elements_to_remove):
    """
    Removes specified elements from the original array.

    Args:
    - original_array (list): The original array.
    - elements_to_remove (list): The elements to be removed from the original array.

    Returns:
    - list: A new array with elements removed.
    """
    return [element for element in original_array if element not in elements_to_remove]

def read_text_file(file_path):
    """
    Reads a text file with two columns and imports data into two arrays.

    Args:
    - file_path (str): The path to the text file.

    Returns:
    - tuple: A tuple containing two arrays representing the data from the two columns.
    """
    column1 = []
    column2 = []

    with open(file_path, 'r') as file:
        for line in file:
            # Assuming columns are separated by a space (you can change it based on your file format)
            data = line.strip().split()
            
            # Assuming there are at least two columns in each line
            column1.append(data[0])
            column2.append(data[1])

    return column1, column2

def get_unlogged_directories(directory):
    """
    Retrieves a list of subdirectories within a specified directory that are not logged as 'logged' in a log file.

    Args:
    - directory (str): The path to the directory to search for unlogged subdirectories.

    Returns:
    - list: A list of subdirectories that are not logged as 'logged' in the 'directories.txt' log file.
    """
    subdirectories=get_subdirectories(directory)
    logged=read_text_file(datadir+"logs/MasterDataLog/directories.txt")
    logged=logged[0][logged[1]=='logged']
    subdirectories=remove_elements(subdirectories, logged)
    return subdirectories
    

def log_finished_directory(directory,status):
    """
    Logs the status of a directory in the 'directories.txt' log file, providing a record of the directory's status.

    Args:
    - directory (str): The directory to be logged.
    - status (str): The status to be appended to the directory in the log file.
    """
    file = open(datadir+'logs/MasterDataLog/directories.txt', 'a')
    file.write(directory+" "+status+"\n")
    file.close()
    return True

def find_directory_log(directory):
    """
    Finds the log file associated with the specified directory.

    Args:
    - directory (str): The directory for which to find the log file.

    Returns:
    - str: The filename of the log file associated with the provided directory.
    """
    logfile=subprocess.check_output("ls "+datadir+directory+"/20??????-log.txt",shell=True)
    logfile=str(logfile)
    return logfile[2:-3]

def sort_masterlog(html_file):
    with open(html_file, 'r') as file:
        html_content = file.read()
    html_content=html_content.split("<b>")
    html_content.sort()
    file = open(html_file, 'w')
    date=time.strftime("%Y%m%d")
    file.write("<p>Last Updated: "+date+"</p>")
    for entry in html_content[::-1]:
        file.write("<b>"+entry)
    file.close()
    return
        
def write_to_master_log(filename,directory):
    """
    Reads the content of a file, formats it as HTML paragraphs, and appends it to the MasterLog.html file.

    Args:
    - filename (str): The path to the input file.
    - directory (str): The name of the directory the referenced data is in.

    Returns:
    - None
    """
    html_string = ""
    with open(filename, 'r') as infile:
        for paragraph in infile.read().split('\n'):
            html_string += "<p>" + paragraph+ "</p>"
    file = open(datadir+'logs/MasterDataLog/MasterLog.html', 'a')
    string_to_write="<b>"+directory+"</b> <br> <p>"+html_string+"</p> <br>"
    file.write(string_to_write)
    file.close()
    return

def upload_masterlog(logfile):
    command ='scp '+logfile+' lsst@emerald.physics.ucdavis.edu:/var/www/html/storm/datalog.html'
    copylog = subprocess.Popen(command, shell=True)
    subprocess.Popen.wait(copylog)

def append_masterlog():
    subdirectories=get_subdirectories(datadir)
    subdirectories.sort()
    recordeddirs=read_text_file(datadir+"logs/MasterDataLog/directories.txt")
    logged=[]
    newcount=0
    for pair in range(len(recordeddirs[0])):
        if recordeddirs[1][pair]=="logged":
            logged.append(recordeddirs[0][pair])
    unloggeddirectories=remove_elements(subdirectories, logged)
    file = open(datadir+'logs/MasterDataLog/directories.txt', 'w')
    file.write(logged[0]+" logged\n")
    for directory in logged[1:]:
        file.write(directory+" logged\n")
    file.close()
    newunloggeddirs=[]
    logupdated=False
    for directory in unloggeddirectories:
        try:
            logname=find_directory_log(directory)
            write_to_master_log(logname,directory)
            log_finished_directory(directory,"logged")
            logupdated=True
            newcount+=1
        except:
            newunloggeddirs.append(directory)
    for directory in newunloggeddirs:
        log_finished_directory(directory,"unlogged")
    if logupdated:
        sort_masterlog(datadir+'logs/MasterDataLog/MasterLog.html')
    upload_masterlog(datadir+'logs/MasterDataLog/MasterLog.html')
    totallogged=newcount+len(logged)
    totalunlogged=len(subdirectories)-totallogged-1
    return newcount,totallogged,totalunlogged

# %%
append_masterlog()
# Out:
# ls: cannot access '/mnt/10TBHDD/data/20220714/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20220721/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20220803/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20220928/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20220929/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20220930/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20221004/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20221005/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230119/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230209/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230214/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230223/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230227/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230301/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230323/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230427/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230428/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230429/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230501/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230502/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230503/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230504/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230508/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230509/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230510/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230511/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230512/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230518/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230523/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230525/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230526/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230530/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230531/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230607/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230608-focusingITL/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230609-PTCFlats/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230609-focusITL/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230612/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230614/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230615/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230616/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230616-Corrpted_datastore/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230620/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230621_run1/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230626/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230628/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230629/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230630/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230705/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230712/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230718-bias_stability_linearly_spaced/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20230720-bias_stability_linear_spaced/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231013/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231016/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231017/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231020-BrighterFatter/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231021/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231026-satellite_streak_crosstalk/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231027-LightLeakShutterOpen/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231027-satellite_streak_crosstalk_fullCCD/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231030-failedPTCrun/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231031-e2vPTC_rband/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/202311-SLAC_New_Voltages_Tests/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231102-1000sDarks/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231102-satellite_streak_crosstalk_fullCCD/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231103-bias_stability_linear_and_log_spaced/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231103-galaxies/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231106/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231107/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231108-cableswap+reseat/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231108-persistence_e2v/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231117-brighter_fatter_spots/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231118-PTC_e2v/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231119-bias_stability/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231121-satellite_streak_crosstalk/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231122-calibration_darks+biases/20??????-log.txt': No such file or directory
# ls: cannot access '/mnt/10TBHDD/data/20231128-LongDarks/20??????-log.txt': No such file or directory
# (0, 68, 76)

# %%
logged
# Out:
# ['l',
#  'l',
#  '20230515-GroundingTests',
#  '20230516',
#  '20230517-2hrDark',
#  '20230517-TurnOnBSSTests',
#  '20230518-spotmasktest',
#  '20230602',
#  '20230606-PTC',
#  '20230609-satellitecalibration',
#  '20230613-bulb_linearity',
#  '20230613-least_bulb',
#  '20230613-lowestStreakFlux',
#  '20230614-bssTests',
#  '20230614-bsstestreseatedcable',
#  '20230614-highADUStreaks',
#  '20230614-newgroundingstrap',
#  '20230621-crosstalkSeg5_6_17',
#  '20230622-crosstalkSeg0_1_2_3_14_15_16_17',
#  '20230622-crosstalkSeg6_7',
#  '20230623-crosstalkSeg4_5_6_7_10_11_12_13',
#  '20230627-LongDarks',
#  '20230714-ITL_Focus',
#  '20230714-crosstalkSeg0_1_12_13',
#  '20230714-crosstalkSeg2_3_14_15',
#  '20230716-crosstalkSeg10_11',
#  '20230717-crosstalkSeg10_11',
#  '20230718-crosstalkAllAmps',
#  '20230718-crosstalkSeg0_1_12_13',
#  '20230718-crosstalkminmax',
#  '20230719-bias_stability_log_scale',
#  '20230721-BiasLevelvsBSS',
#  '20230724-CrosstalkYFilter',
#  '20230725-BrighterFatterRFilter',
#  '20230725-BrighterFatterYFilter',
#  '20230725-ITL_Focus',
#  '20230726-ITL_Focus',
#  '20230728-ITL_Focus',
#  '20230728-persistence',
#  '20230730-ITL_PTC',
#  '20230801-midlineCrosstalk',
#  '20230802-BSSvCrosstalk',
#  '20230802-crosstalkHysteresis',
#  '20230804-warmflats',
#  '20231020-PTC_r-band',
#  '20231020-e2v_Focus',
#  '20231020-e2v_Focus1',
#  '20231022-satellite_streak_crosstalk',
#  '20231023-e2V_LongDarks',
#  '20231025-2hrDarks',
#  '20231025-calibrationDarks',
#  '20231026-LightLeakTest',
#  '20231030-SuperFlats',
#  '20231103-e2v_Focus',
#  '20231107-e2v_Focus',
#  '20231109-e2v_Focus',
#  '20231109-perisitence',
#  '20231117-calibration_darks+biases',
#  '20231117-e2v_Focus',
#  '20231118-superflats',
#  '20231122-superflats',
#  '20231127-persistence',
#  '20231201-SequencerRuns-failed',
#  '20231210-SequencerRuns',
#  '20231212-sequencerCrosstalkRuns',
#  '20231213-persistenceSequencerRuns',
#  '20240108-SequencerRuns',
#  '20240108-persistenceSequencerRuns',
#  '20240109-sequencerCrosstalkRuns']

# %%
text="<b> 311no you don't</b> yes I do <b> 21no you really dont</b>yes I do"
a=text.split("<b>")

# %%
a
# Out:
# ['', " 311no you don't</b> yes I do ", ' 21no you really dont</b>yes I do']

# %%
a.sort()

# %%
a
# Out:
# ['', ' 21no you really dont</b>yes I do', " 311no you don't</b> yes I do "]

# %%
a[::-1]
# Out:
# [" 311no you don't</b> yes I do ", ' 21no you really dont</b>yes I do', '']
